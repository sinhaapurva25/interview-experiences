# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'Samsung-Dataset.csv')
df.head(1)
# Out:
#      ID        0         1         2         3        4         5         6  \
# 0  1460 -0.13215  0.665297 -0.064984 -0.682743 -1.67012 -2.038328 -0.545154
#
#          7         8  ...      2031     2032      2033      2034      2035  \
# 0  0.31071  1.383457  ... -1.861042 -0.54705  0.027867  0.195051 -1.528746
#
#       2036      2037      2038      2039  target
# 0 -0.82043 -0.520177 -0.018556  0.115196       0
#
# [1 rows x 2042 columns]

# %%
df.isnull().values.any(), df.isna().values.any()
# Out:
# (True, True)

# %%
cols = df.columns
for i in cols:
    med = np.median(df[i])
    df[i].fillna(med)

# %%
df.isnull().values.any(), df.isna().values.any()
# Out:
# (True, True)

# %%
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.8

train = df[msk]
test = df[~msk]

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df.hist(bins=len(cols[:5]))
plt.show()
